# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import randn
from io import BytesIO
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
from openpyxl import Workbook
import openpyxl as px

# %%
dfdata2010 = pd.read_csv('Dataset2010.csv')

# %%
#dfdataoverall = px.load_workbook('Datasetoverall.xlsx')

# %%
dfdata2016 = pd.read_csv('Dataset2016.csv')

# %%
dfdataoverall = pd.read_csv('Datasetoverall.csv')

# %%
print("Country")
len(dfdata2010)
# Out:
# Country
# 158

# %%
print("Country")
len(dfdata2016)
# Out:
# Country
# 157

# %%
dfdata2010.columns
# Out:
# Index(['Country', 'Region', 'HappinessRank', 'HappinessScore', 'StandardError',
#        'Economy', 'Family', 'LifeExpectancy', 'Freedom',
#        'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
dfdata2016.columns
# Out:
# Index(['Country', 'Region', 'HappinessRank', 'HappinessScore',
#        'Lower Confidence Interval', 'Upper Confidence Interval', 'Economy',
#        'Family', 'LifeExpectancy', 'Freedom', 'PerceptionsofCorruption',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
#Showing Top 10 Happiest Countries in 2010
happiest2010 = dfdata2010.sort_values(ascending=False, by=['HappinessScore'])
happiest2010[:10].ix[:]
# Out:
#        Country                     Region  HappinessRank  HappinessScore  \
# 0  Switzerland             Western Europe              1           7.587
# 1      Iceland             Western Europe              2           7.561
# 2      Denmark             Western Europe              3           7.527
# 3       Norway             Western Europe              4           7.522
# 4       Canada              North America              5           7.427
# 5      Finland             Western Europe              6           7.406
# 6  Netherlands             Western Europe              7           7.378
# 7       Sweden             Western Europe              8           7.364
# 8  New Zealand  Australia and New Zealand              9           7.286
# 9    Australia  Australia and New Zealand             10           7.284
#
#    StandardError  Economy  Family  LifeExpectancy  Freedom  \
# 0          0.034    1.397   1.350           0.941    0.666
# 1          0.049    1.302   1.402           0.948    0.629
# 2          0.033    1.325   1.361           0.875    0.649
# 3          0.039    1.459   1.331           0.885    0.670
# 4          0.036    1.326   1.323           0.906    0.633
# 5          0.031    1.290   1.318           0.889    0.642
# 6          0.028    1.329   1.280           0.893    0.616
# 7          0.032    1.332   1.289           0.911    0.660
# 8          0.034    1.250   1.320           0.908    0.639
# 9          0.041    1.334   1.309           0.932    0.651
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.420       0.297              2.517
# 1                          0.141       0.436              2.702
# 2                          0.484       0.341              2.492
# 3                          0.365       0.347              2.465
# 4                          0.330       0.458              2.452
# 5                          0.414       0.234              2.620
# 6                          0.318       0.476              2.466
# 7                          0.438       0.363              2.371
# 8                          0.429       0.475              2.264
# 9                          0.356       0.436              2.266

# %%
#Showing Top 10 Happiest Countries in 2016
happiest2016 = dfdata2016.sort_values(ascending=False, by=['HappinessScore'])
happiest2016[:10].ix[:]
# Out:
#        Country                     Region  HappinessRank  HappinessScore  \
# 0      Denmark             Western Europe              1           7.526
# 1  Switzerland             Western Europe              2           7.509
# 2      Iceland             Western Europe              3           7.501
# 3       Norway             Western Europe              4           7.498
# 4      Finland             Western Europe              5           7.413
# 5       Canada              North America              6           7.404
# 6  Netherlands             Western Europe              7           7.339
# 7  New Zealand  Australia and New Zealand              8           7.334
# 8    Australia  Australia and New Zealand              9           7.313
# 9       Sweden             Western Europe             10           7.291
#
#    Lower Confidence Interval  Upper Confidence Interval  Economy   Family  \
# 0                      7.460                      7.592  1.44178  1.16374
# 1                      7.428                      7.590  1.52733  1.14524
# 2                      7.333                      7.669  1.42666  1.18326
# 3                      7.421                      7.575  1.57744  1.12690
# 4                      7.351                      7.475  1.40598  1.13464
# 5                      7.335                      7.473  1.44015  1.09610
# 6                      7.284                      7.394  1.46468  1.02912
# 7                      7.264                      7.404  1.36066  1.17278
# 8                      7.241                      7.385  1.44443  1.10476
# 9                      7.227                      7.355  1.45181  1.08764
#
#    LifeExpectancy  Freedom  PerceptionsofCorruption  Generosity  \
# 0         0.79504  0.57941                  0.44453     0.36171
# 1         0.86303  0.58557                  0.41203     0.28083
# 2         0.86733  0.56624                  0.14975     0.47678
# 3         0.79579  0.59609                  0.35776     0.37895
# 4         0.81091  0.57104                  0.41004     0.25492
# 5         0.82760  0.57370                  0.31329     0.44834
# 6         0.81231  0.55211                  0.29927     0.47416
# 7         0.83096  0.58147                  0.41904     0.49401
# 8         0.85120  0.56837                  0.32331     0.47407
# 9         0.83121  0.58218                  0.40867     0.38254
#
#    Dystopia Residual
# 0            2.73939
# 1            2.69463
# 2            2.83137
# 3            2.66465
# 4            2.82596
# 5            2.70485
# 6            2.70749
# 7            2.47553
# 8            2.54650
# 9            2.54734

# %%
#Showing Top 10 Least Happy Countries in 2010
happiest2010 = dfdata2010.sort_values(ascending=False, by=['HappinessScore'])
happiest2010[-10:].ix[:]
# Out:
#           Country                           Region  HappinessRank  \
# 148          Chad               Sub-Saharan Africa            149
# 149        Guinea               Sub-Saharan Africa            150
# 150   Ivory Coast               Sub-Saharan Africa            151
# 151  Burkina Faso               Sub-Saharan Africa            152
# 152   Afghanistan                    Southern Asia            153
# 153        Rwanda               Sub-Saharan Africa            154
# 154         Benin               Sub-Saharan Africa            155
# 155         Syria  Middle East and Northern Africa            156
# 156       Burundi               Sub-Saharan Africa            157
# 157          Togo               Sub-Saharan Africa            158
#
#      HappinessScore  StandardError  Economy  Family  LifeExpectancy  Freedom  \
# 148           3.667          0.038    0.342   0.761           0.150    0.235
# 149           3.656          0.036    0.174   0.465           0.240    0.377
# 150           3.655          0.051    0.465   0.771           0.152    0.469
# 151           3.587          0.043    0.258   0.852           0.271    0.395
# 152           3.575          0.031    0.320   0.303           0.303    0.234
# 153           3.465          0.035    0.222   0.774           0.429    0.592
# 154           3.340          0.037    0.287   0.354           0.319    0.485
# 155           3.006          0.050    0.663   0.475           0.722    0.157
# 156           2.905          0.087    0.015   0.416           0.224    0.119
# 157           2.839          0.067    0.209   0.140           0.284    0.365
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 148                          0.053       0.184              1.943
# 149                          0.121       0.287              1.992
# 150                          0.179       0.202              1.417
# 151                          0.128       0.217              1.465
# 152                          0.097       0.365              1.952
# 153                          0.552       0.226              0.670
# 154                          0.080       0.183              1.633
# 155                          0.189       0.472              0.329
# 156                          0.101       0.197              1.833
# 157                          0.107       0.167              1.567

# %%
#Showing Top 10 Least Happy Countries in 2010
happiest2016 = dfdata2016.sort_values(ascending=False, by=['HappinessScore'])
happiest2016[-10:].ix[:]
# Out:
#          Country                           Region  HappinessRank  \
# 147   Madagascar               Sub-Saharan Africa            148
# 148     Tanzania               Sub-Saharan Africa            149
# 149      Liberia               Sub-Saharan Africa            150
# 150       Guinea               Sub-Saharan Africa            151
# 151       Rwanda               Sub-Saharan Africa            152
# 152        Benin               Sub-Saharan Africa            153
# 153  Afghanistan                    Southern Asia            154
# 154         Togo               Sub-Saharan Africa            155
# 155        Syria  Middle East and Northern Africa            156
# 156      Burundi               Sub-Saharan Africa            157
#
#      HappinessScore  Lower Confidence Interval  Upper Confidence Interval  \
# 147           3.695                      3.621                      3.769
# 148           3.666                      3.561                      3.771
# 149           3.622                      3.463                      3.781
# 150           3.607                      3.533                      3.681
# 151           3.515                      3.444                      3.586
# 152           3.484                      3.404                      3.564
# 153           3.360                      3.288                      3.432
# 154           3.303                      3.192                      3.414
# 155           3.069                      2.936                      3.202
# 156           2.905                      2.732                      3.078
#
#      Economy   Family  LifeExpectancy  Freedom  PerceptionsofCorruption  \
# 147  0.27954  0.46115         0.37109  0.13684                  0.07506
# 148  0.47155  0.77623         0.35700  0.31760                  0.05099
# 149  0.10706  0.50353         0.23165  0.25748                  0.04852
# 150  0.22415  0.31090         0.18829  0.30953                  0.11920
# 151  0.32846  0.61586         0.31865  0.54320                  0.50521
# 152  0.39499  0.10419         0.21028  0.39747                  0.06681
# 153  0.38227  0.11037         0.17344  0.16430                  0.07112
# 154  0.28123  0.00000         0.24811  0.34678                  0.11587
# 155  0.74719  0.14866         0.62994  0.06912                  0.17233
# 156  0.06831  0.23442         0.15747  0.04320                  0.09419
#
#      Generosity  Dystopia Residual
# 147     0.22040            2.15075
# 148     0.31472            1.37769
# 149     0.24063            2.23284
# 150     0.29914            2.15604
# 151     0.23552            0.96819
# 152     0.20180            2.10812
# 153     0.31268            2.14558
# 154     0.17517            2.13540
# 155     0.48397            0.81789
# 156     0.20290            2.10404
